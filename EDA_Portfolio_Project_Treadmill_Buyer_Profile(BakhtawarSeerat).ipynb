# %% [markdown]
# #EDA Portfolio Project - Treadmill Buyer Profile

# %% [markdown]
# **Project Details:**
#
# The market research team at AeroFit wants to identify the characteristics of the target audience for each type of treadmill oƯered by the company, to provide a better recommendation of the treadmills to new customers. The team decides to investigate whether there are diƯerences across the product with respect to customer
# characteristics.
#
# **Product Portfolio:**
# *   The KP281 is an entry-level treadmill that sells for $1,500;
#
# *   The KP481 is for mid-level runners and sells for $1,750;
#
# *   The KP781 treadmill have advanced features, and it sells for $2,500.
#
# **Data Description:**
#
# The company collected data on individuals who purchased a treadmill from the AeroFit stores during the prior three months. The dataset in aerofit_treadmill_data.csv has the following features:
#
# *   Product - product purchased: KP281, KP481, or KP781
# *   Age - in years
# *   Gender - male/female
# *   Education - in years
# *   MaritalStatus - single or partnered
# *   Usage - the average number of times the customer plans to use the treadmill
# each week
# *   Fitness - self-rated fitness on a 1-5 scale, where 1 is the poor shape and 5 is the excellent shape
# *   Income - annual income in US dollars
# *   Miles - the average number of miles the customer expects to walk/run each week

# %% [markdown]
# ##**1. Data Exploration and Processing:**

# %% [markdown]
# ###**Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###**Import Data**

# %%
data=pd.read_csv("/content/aerofit_treadmill_data.csv")

# %% [markdown]
# ###**Read Dataframe**

# %%
data
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# 5     KP281   20  Female         14     Partnered      3        3   32973
# 6     KP281   21  Female         14     Partnered      3        3   35247
# 7     KP281   21    Male         13        Single      3        3   32973
# 8     KP281   21    Male         15        Single      5        4   35247
# 9     KP281   21  Female         15     Partnered      2        3   37521
# 10    KP281   22    Male         14        Single      3        3   36384
# 11    KP281   22  Female         14     Partnered      3        2   35247
# ...

# %% [markdown]
# ###**Reading Dataframe top 10 rows**

# %%
data.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47
# 5   KP281   20  Female         14     Partnered      3        3   32973     66
# 6   KP281   21  Female         14     Partnered      3        3   35247     75
# 7   KP281   21    Male         13        Single      3        3   32973     85
# 8   KP281   21    Male         15        Single      5        4   35247    141
# 9   KP281   21  Female         15     Partnered      2        3   37521     85

# %% [markdown]
# ###**Reading Dataframe last 10 rows**

# %%
data.tail(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 170   KP781   31    Male         16     Partnered      6        5   89641
# 171   KP781   33  Female         18     Partnered      4        5   95866
# 172   KP781   34    Male         16        Single      5        5   92131
# 173   KP781   35    Male         16     Partnered      4        5   92131
# 174   KP781   38    Male         18     Partnered      5        5  104581
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 170    260
# 171    200
# 172    150
# 173    360
# 174    150
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %% [markdown]
# ###**A sample of Data**

# %%
data.sample(5)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 141   KP781   22    Male         16        Single      3        5   54781
# 5     KP281   20  Female         14     Partnered      3        3   32973
# 59    KP281   33  Female         16        Single      2        2   55713
# 61    KP281   34    Male         16        Single      4        5   51165
# 111   KP481   27    Male         14        Single      4        2   45480
#
#      Miles
# 141    120
# 5       66
# 59      38
# 61     169
# 111     53

# %% [markdown]
# ###**All Data**

# %%
pd.set_option('display.max_rows',180 )
data
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# 5     KP281   20  Female         14     Partnered      3        3   32973
# 6     KP281   21  Female         14     Partnered      3        3   35247
# 7     KP281   21    Male         13        Single      3        3   32973
# 8     KP281   21    Male         15        Single      5        4   35247
# 9     KP281   21  Female         15     Partnered      2        3   37521
# 10    KP281   22    Male         14        Single      3        3   36384
# 11    KP281   22  Female         14     Partnered      3        2   35247
# ...

# %% [markdown]
# ### **Information about dataset**
#
# - dataframe
# - total number of rows
# - total number of columns
# - column names + missing values + data types
# - memory usage

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# ###**Shape of DataFrame**

# %%
data.shape
# Out:
# (180, 9)

# %% [markdown]
# The data has 180 rows and 9 coloumns

# %% [markdown]
# ###**Datatype of columns**

# %%
data.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %% [markdown]
# 3 attributes are categorical
# 6 attributes are numerical

# %% [markdown]
# ###**Missing value detection**

# %%
data.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
#total missing cells in the dataset
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# There are no missing values in data
#
# We can further visualize this as follows

# %%
# !pip install missingno

# %%
import missingno as msno

# %%
bar = msno.bar(data)
bar
# Out:
# <Axes: >

# %%
msno.matrix(data)
# Out:
# <Axes: >

# %% [markdown]
# ### **Checking duplicate values in the dataset**

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate rows in data.

# %% [markdown]
# ## **2. Statistical Summary:**

# %%
data.describe(include="int64")
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
data.describe(include="object")
# Out:
#        Product Gender MaritalStatus
# count      180    180           180
# unique       3      2             2
# top      KP281   Male     Partnered
# freq        80    104           107

# %%
data.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# **Provide an analysis of the statistical summary in few lines for both categorical and numerical features.**

# %% [markdown]
# The dataset comprises 180 observations (rows) and 9 features (columns)
#
#
# The dataset contains a mix of categorical and numerical variables:
#
#  Categorical Variables
#
#        Product
#
#        Represents the type of treadmill purchased (KP281, KP481, KP781).
#        There are 180 observations of Product.
#        KP281 is the most frequent value that apears 80 times.
#
#        Gender
#
#        Indicates the gender of the customers (Male, Female). There are 180 observations of Gender.
#        Male is the most frequent value that apears 104 times.
#
#        MaritalStatus
#
#        Classifies customers as either Single or Partnered. There are 180 observations of MaritalStatus.
#        Partnered is the most frequent value that apears 107 times.
#
#
#  Numerical Variables
#
#        Age
#
#        The age of customers in years.
#        There are 180 observations of Age.
#        Mean Age is 15.6
#        Standard Deviation of age is 6.9
#        Minimum age is 18.
#        Maximum Age is 21
#        25th Percentile: 24
#        50th Percentile:26
#        75th Percentile:33
#
#        Education
#
#        The number of years of education completed.
#        There are 180 observations of Education.
#        Mean Education is 28.79
#        Standard Deviation of Education is 1.62
#        Minimum Education is 12.
#        Maximum is 50
#        25th Percentile: 14
#        50th Percentile:16
#        75th Percentile:16
#
#        Usage
#
#        The average number of times the customer plans to use the treadmill each week.
#        There are 180 observations of Usage.
#        Mean Usage is 3.45
#        Standard Deviation of Usage is 1.08
#        Minimum Usage is 2.
#         Maximum Usage is 7
#        25th Percentile: 3
#        50th Percentile:3
#        75th Percentile:4
#
#        Fitness
#
#        Self-rated fitness on a 1-5 scale, where 1 is the poor shape and 5 is the excellent shape.
#        There are 180 observations of Fitness.
#        Mean Fitness is 3.31
#        Standard Deviation of Fitness is 0.96
#        Minimum Fitness is 1
#        Maximum Fitness is 5
#        25th Percentile: 3
#        50th Percentile:3
#        75th Percentile:4
#
#        Income
#
#        The annual income of customers in US dollars.
#        There are 180 observations of Income.
#        Mean Income is 53719.57
#        Standard Deviation of Income is 16506.68
#        Minimum Income is 29562
#        Maximum Income is 104581
#        25th Percentile: 44058.75
#        50th Percentile:50596.50
#        75th Percentile:58668.00
#
#        Miles
#
#        The average number of miles customers expect to walk/run each week.
#        There are 180 observations of Miles.
#        Mean Miles is 103.19
#        Standard Deviation of Miles is 51.86
#        Minimum Miles is 21.00
#        Maximum Miles is 360.00
#        25th Percentile: 66.00
#        50th Percentile:94.00
#        75th Percentile:114.75

# %% [markdown]
# ##**3. Non-Graphical Analysis:**

# %% [markdown]
# ###**Value Counts for all categorical features**

# %%
for c in data.columns:
  if data[c].dtype!='int64':
    print(data[c].value_counts())
    print("_________________________")
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: count, dtype: int64
# _________________________
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64
# _________________________
# MaritalStatus
# Partnered    107
# Single        73
# Name: count, dtype: int64
# _________________________

# %% [markdown]
# There are three Treadmill Products i.e KP281 , KP481 , KP781.
# 80 customers purchased KP281.
# 60 customers purchased KP481.
# 40 customers purchased KP781.
#
# Gender column can have two values i.e Male and Female.
# 104 customers are Partnered.
# 76 customers are single.
#
#
# Marital Status column can have two values i.e Partnered and Single.
# 107 customers are Partnered.
# 73 customers are Single.

# %% [markdown]
# ###**Unique Attributes for all categorical features**

# %%
for c in data.columns:
  if data[c].dtype!='int64':
    print("Total Unique values of column",c,":", data[c].nunique())
    print("Unique values of column", c,":", data[c].unique())
    print("____________________________________")
# Out:
# Total Unique values of column Product : 3
# Unique values of column Product : ['KP281' 'KP481' 'KP781']
# ____________________________________
# Total Unique values of column Gender : 2
# Unique values of column Gender : ['Male' 'Female']
# ____________________________________
# Total Unique values of column MaritalStatus : 2
# Unique values of column MaritalStatus : ['Single' 'Partnered']
# ____________________________________

# %% [markdown]
# ##**4. Graphical Analysis:**

# %% [markdown]
# ###**Univariate Analysis - Numerical features:**

# %% [markdown]
# ####Distribution Plot

# %%
for col in data.select_dtypes(include="number").columns:
  print(col)
  sns.histplot(data[col],kde=True)
  plt.show()
# Out:
# Age
# Education
# Usage
# Fitness
# Income
# Miles

# %%
plt.figure(figsize=(15,5))   #width, heigh

for index,col in enumerate(data.select_dtypes(include="number").columns):
  plt.subplot(1,6,index+1)     #rows, column, position
  sns.histplot(data[col],kde=True)
  plt.title(f"Distrbution of {col}")
  plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# Fom distribution, we can infer from these distribution plots, that all these attribute values are left skewed.

# %% [markdown]
# ####Count Plot

# %%
plt.hist(data["Age"],color="steelblue",edgecolor ="black")
plt.show()

# %%
plt.hist(data["Education"],color="steelblue",edgecolor ="black")
plt.show()

# %%
plt.hist(data["Usage"],color="steelblue",edgecolor ="black")
plt.show()

# %%
plt.hist(data["Fitness"],color="steelblue",edgecolor ="black")
plt.show()

# %%
plt.hist(data["Income"],color="steelblue",edgecolor ="black")
plt.show()

# %%
plt.hist(data["Miles"],color="steelblue",edgecolor ="black")
plt.show()

# %% [markdown]
# The count of respective bins of data is plotted for all numeric attributes.

# %% [markdown]
# ####Box plot

# %%
plt.figure(figsize=(10,5))
for i, column in enumerate(data.select_dtypes(include="number").columns):
  plt.subplot(1,6,i+1)
  sns.boxplot(data[column])
  plt.title(column)

plt.tight_layout()
plt.show()

# %% [markdown]
# From these boxplots, we can have an idea about the value ranges of numeric attributes.
#
# Moreover, outliers can also be seen from these boxplots.

# %% [markdown]
# ###**Univariate Analysis - Categorical features:**

# %% [markdown]
# ####Count Plot

# %%
plt.figure(figsize=(20,5))

for i,column in enumerate(data.select_dtypes(include="object").columns):

  plt.subplot(1,6,i+1)
  sns.countplot(x=data[column])
  plt.title(column)
  plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# From these countplots of categorical data, we can infer:
#
# The most purchased product is KP281 and least is KP781.
#
# Male customers are more than female customers.
#
# Partnered customers are more than Single Customers.

# %% [markdown]
# ###**Bivariate Analysis:**

# %% [markdown]
# ####Check features effect on the product purchased e.g.

# %% [markdown]
# #####Product vs Gender

# %%
#  Gender vs Product Purchased
sns.countplot(data=data, x='Product', hue='Gender')
plt.title('Product Purchased by Gender')
plt.xlabel('Product')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# KP281 is equally popular among Male and Female Customers.
#
# KP481 has more Male customers than female customers.
#
# KP781 has a major Customer segment from male customers.

# %% [markdown]
# #####Product vs MaritalStatus

# %%
# Marital Status vs Product Purchased
sns.countplot(data=data, x='Product', hue='MaritalStatus')
plt.title('Product Purchased by MaritalStatus')
plt.xlabel('Product')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# KP281  mostly has Partnered Customers as compared to Singles.
#
# KP481 also has more Partnered Customers than Singles.
#
# KP781 has slightly more Partnered Customers than Singles.

# %% [markdown]
# #####Product vs Age

# %%
# Product vs Age
sns.boxplot(x='Product',y='Age',data=data)
plt.title('Product Purchased by Age')
plt.show()

# %% [markdown]
# KP781 has younger customers as compared to customers of to KP281 and KP481.

# %%
# Product vs Education
sns.boxplot(x='Product',y='Education',data=data)
plt.title('Product Purchased by Education')
plt.show()

# %%
# Product vs Usage
sns.boxplot(x='Product',y='Usage',data=data)
plt.title('Product Purchased by Usage')
plt.show()

# %%
# Product vs Fitness
sns.boxplot(x='Product',y='Fitness',data=data)
plt.title('Product Purchased by Fitness')
plt.show()

# %%
# Product vs Income
sns.boxplot(x='Product',y='Income',data=data)
plt.title('Product Purchased by Income')
plt.show()

# %%
# Product vs Miles
sns.boxplot(x='Product',y='Miles',data=data)
plt.title('Product Purchased by Miles')
plt.show()

# %% [markdown]
# ###**Multivariate Analysis:**

# %% [markdown]
# ####Create pairplots to show relationship of features

# %%
sns.pairplot(data, hue ="Product")
plt.show()

# %% [markdown]
# ##**5. Correlation Analysis:**

# %% [markdown]
# ###Show the correlation matrix on heatmap and write your observation of findings in few lines.

# %%
data.corr(numeric_only=True)
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(data.corr(numeric_only=True),annot=True)
plt.show()

# %% [markdown]
# **Observation of findings**
#
# *   All the numerical variables are positively coreelated.
#
# *   Miles has highest positive correlation with: Finess(0.79) followed by Usage(0.76) and least correlated to Age(0.037)
#
# *   Income is highly correlated to Education(0.63) and least correlated to Age(0.51)
#
# *   Fitness has highest positive correlation with Miles(0.79) followed by Usage(0.67) and least correlated to Age(0.061)
#
# *   Usage is highly correlated to Miles(0.76) followed by Fitness(0.67) and least correlated to Age(0.015)
#
# *   Education is highly correlated to Income(0.63) and least correlated to Age(0.28)
# *   Age is highly correlated to Income(0.51) and least correlated with usage(0.037)

# %% [markdown]
# ##**6. Outlier Detection:**

# %% [markdown]
# ###Check for the outliers by using the IQR method.

# %%
for column in data.select_dtypes(include="number").columns:
  Q1 = data[column].quantile(0.25)
  Q3 = data[column].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5*IQR
  upper_bound = Q3 + 1.5*IQR
  outliers = data[(data[column] <lower_bound) | (data[column] > upper_bound)]
  print("Name of Column:", column)
  print(outliers)
  print("________________________________________________________________________")
# Out:
# Name of Column: Age
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 78    KP281   47    Male         16     Partnered      4        3   56850
# 79    KP281   50  Female         16     Partnered      3        3   64809
# 139   KP481   48    Male         16     Partnered      2        3   57987
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 78      94
# 79      66
# 139     64
# 178    120
# 179    180
# ________________________________________________________________________
# Name of Column: Education
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 156   KP781   25    Male         20     Partnered      4        5   74701
# 157   KP781   26  Female         21        Single      4        3   69721
# 161   KP781   27    Male         21     Partnered      4        4   90886
# ...

# %% [markdown]
# ##**7. Conditional Probabilities:**

# %% [markdown]
# ###What percent of customers have purchased KP281, KP481, or KP781?

# %%
product_counts = data["Product"].value_counts()
total = data["Product"].value_counts().sum()
percent_customers=(product_counts/total) *100
print(percent_customers)
# Out:
# Product
# KP281    44.444444
# KP481    33.333333
# KP781    22.222222
# Name: count, dtype: float64

# %% [markdown]
# 44.44% customers purchase KP281
#
# 33.33%  customers purchase KP481
#
# 22.22% customers purchase KP781

# %% [markdown]
# ###Create frequency tables and calculate the percentage as follows:

# %% [markdown]
# ####Product - Gender

# %% [markdown]
# #####Percentage of a Male customer purchasing a treadmill

# %%
product_counts = data[data["Gender"]=='Male'].value_counts().sum()
total = data["Gender"].value_counts().sum()
percent_customers=(product_counts/total) *100
print(percent_customers)
# Out:
# 57.77777777777777

# %% [markdown]
# 57.78% customers purchasing a treadmill are Male

# %% [markdown]
# #####Percentage of a Female customer purchasing KP781 treadmill

# %%
product_counts = data[(data["Gender"]=='Female')  & (data["Product"]=='KP781')].value_counts().sum()
total = data[data["Gender"]=='Female'].value_counts().sum()
percent_customers=(product_counts/total) *100
print(percent_customers)
# Out:
# 9.210526315789473

# %% [markdown]
# Percentage of a Female customer purchasing KP781 treadmill is 9.21%

# %% [markdown]
# #####Probability of a customer being a Female given that Product is KP281

# %%
product_counts = data[(data["Gender"]=='Female')  & (data["Product"]=='KP281')].value_counts().sum()
total = data[data["Product"]=='KP281'].value_counts().sum()
prob_customers=(product_counts/total)
print(prob_customers)
# Out:
# 0.5

# %% [markdown]
# Probability of a customer being a Female given that Product is KP281 is 0.50

# %% [markdown]
# ####Product - Age

# %% [markdown]
# #####Percentage of customers with Age between 20s and 30s among all customers

# %%
product_counts = data[(data["Age"]>20)  &(data["Age"]<30)].value_counts().sum()
total = data.value_counts().sum()
percent_customers=(product_counts/total) *100
print(percent_customers)
# Out:
# 57.22222222222222

# %% [markdown]
# Percentage of customers between 20 and 30 years of Age is 57.22%

# %% [markdown]
# ####Product - Income

# %% [markdown]
# #####Percentage of a low-income customer purchasing a treadmill

# %%
product_counts = data[data["Income"]<50000].value_counts().sum()
total = data.value_counts().sum()
percent_customers=(product_counts/total) *100
print(percent_customers)
# Out:
# 46.111111111111114

# %% [markdown]
# Percentage of a low-income(less than $50,000) customer purchasing a treadmill is 46.11%

# %% [markdown]
# #####Percentage of a high-income customer purchasing KP781 treadmill

# %%
product_counts = data[(data["Income"]>50000)  & (data["Product"]=='KP781')].value_counts().sum()
total = data.value_counts().sum()
percent_customers=(product_counts/total) *100
print(percent_customers)
# Out:
# 19.444444444444446

# %% [markdown]
# Percentage of a high-income(more than $50,000) customer purchasing a KP781 treadmill is 19.44%

# %% [markdown]
# #####Percentage of customer with high-income salary buying treadmill given that Product is KP781

# %%
product_counts = data[(data["Income"]>50000)  & (data["Product"]=='KP781')].value_counts().sum()
total = data[data["Product"]=='KP781'].value_counts().sum()
percent_customers=(product_counts/total) *100
print(percent_customers)
# Out:
# 87.5

# %% [markdown]
# Percentage of customer with high-income salary buying treadmill given that Product is KP781: 87.50%

# %% [markdown]
# ####Product - Fitness

# %% [markdown]
# #####Percentage of customers that have fitness level 5

# %%
product_counts = data[data["Fitness"]==5].value_counts().sum()
total = data["Fitness"].value_counts().sum()
percent_customers=(product_counts/total) *100
print(percent_customers)
# Out:
# 17.22222222222222

# %% [markdown]
# Percentage of customers that have fitness level 5 is 17.22%

# %% [markdown]
# #####Percentage of a customer with Fitness Level 5 purchasing KP781treadmill

# %%
product_counts = data[(data["Fitness"]==5) & (data["Product"]=="KP781")].value_counts().sum()
total = data[data["Fitness"]==5].value_counts().sum()
percent_customers=(product_counts/total) *100
print(percent_customers)
# Out:
# 93.54838709677419

# %% [markdown]
# Percentage of a customer with Fitness Level 5 purchasing KP781treadmill is 93.55%

# %% [markdown]
# #####Percentage of customer with fitness level 5 buying KP781 treadmill  (Repeated Question)

# %%
product_counts = data[(data["Fitness"]==5) & (data["Product"]=="KP781")].value_counts().sum()
total = data[data["Fitness"]==5].value_counts().sum()
percent_customers=(product_counts/total) *100
print(percent_customers)
# Out:
# 93.54838709677419

# %% [markdown]
# ####Product - MaritalStatus

# %% [markdown]
# #####Percentage of a customers who are partnered using treadmills

# %%
product_counts = data[(data["MaritalStatus"]=='Partnered') ].value_counts().sum()
total = data["MaritalStatus"].value_counts().sum()
percent_customers=(product_counts/total) *100
print(percent_customers)
# Out:
# 59.44444444444444

# %% [markdown]
# Percentage of partnered customers using treadmills: 59.44%

# %% [markdown]
# ##**8. Actionable Insights & Recommendations:**

# %% [markdown]
# ###Provide detailed report on the actionable insights and recommendations according to your observations.

# %% [markdown]
# ###**Data Profiling**

# %%
# !pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport

# %%
Profile = ProfileReport(data,title="Treadmil dataset Profile")

# %%
Profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.14.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-03-15 18:15:22.483271&quot;&gt;&lt;title&gt;Treadmil dataset Profile&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
Profile.to_file("Data_Report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ###**Insights and Recommendations**

# %% [markdown]
# **EDA Portfolio Project - Treadmill Buyer Profile**
#
# - Lets explore insights related to customer characteristics and their purchasing behavior regarding Aerofit's treadmill products.
#
# **Insights and Recommendations**
#
# - The analysis of AeroFit's treadmill products reveals customer profiles for each product line, highlighting differences in income, fitness level, and frequency of usage.
#
#
# -Overall the most selling treadmil is KP281, followed by KP481 and then KP781
#
# **Gender**
#
# -Overall there are more Male customers of the treadmills as compared to Female customers.
#
#
# **MaritalStatus**
#
# -Overall there are more Partnered customers of the treadmills as compared to Single customers.
#
#
# **Age**
#
# -KP781 is more popular among young customers as compared to KP481, and KP781.
#
#
# **Education**
#
# -The customers of KP781 are more highly educated as comapred to customers of KP481, and KP281.
#
#
# **Fitness, Miles and Usage:**
#
# -The customers of KP781 are more serious about their Fitness level(self rating of Fitness, Number of Miles they expect to run/week and Number of times they intend to use the treadmill) as comapred to customers of KP481 and KP281.
#
#
# **Income**
#
# -The customers of KP781 are more high Income levels , followed by the Income level of KP481 and then followed by the income level of customers of KP281.
#
#
# *  These insights can be used to target the relevant audiences and develop the right marketing strategy and increase the sale of all the three categories of treadmills.So that the right product reaches the right customer market.
#
# *  e.g. KP781 is popular among younger, highly educated, highly paid and more serious customers. So, the relant customers should be reached considering all these points.
